# %%
import pandas as pd

df = pd.read_csv('CMV.csv')

# %%
df['Data'] = pd.to_datetime(df['Data'])

# %%
meses_ptbr = {'January':'Janeiro', 
              'February':'Fevereiro',
              'March':'Março',
              'April':'Abril',
              'May':'Maio',
              'June':'Junho', 
              'July':'Julho', 
              'August':'Agosto', 
              'September':'Setembro', 
              'October':'Outubro', 
              'November':'Novembro', 
              'December':'Dezembro'}
df['Data'].dt.month_name().replace(meses_ptbr)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [265], in <cell line: 13>()
#       1 meses_ptbr = {'January':'Janeiro',
#       2               'February':'Fevereiro',
#       3               'March':'Março',
#    (...)
#      11               'November':'Novembro',
#      12               'December':'Dezembro'}
# ---> 13 df['Data'].dt.month_name().replace(meses_ptbr)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'Data'

# %%
import pandas as pd
df_ds = pd.read_csv('df_receitas.csv')
dfs = [df_ds]
df_final = pd.concat(dfs)

df_final['Data'] = pd.to_datetime(df_final['Data'])
mask = df_final[(df_final['Data'] <= '2022-12-30')]
mask.head()
# Out:
#    deducoes   Valor      Categoria  Fixo  Efetuado        CPF/CNPJ  UF  \
# 0     32.50  220.69     LojaFisica     0         1  913.264.607-06  RJ
# 1     97.92  664.91     LojaFisica     0         1  520.402.836-68  MG
# 2     12.11   82.22  LojaIntegrada     0         1  083.623.246-19  MG
# 3      1.92   19.66  LojaIntegrada     0         1  083.623.246-19  MG
# 4     37.34  200.00     LojaFisica     0         1  322.747.856-00  SP
#
#   CÃ³digo (SKU)         NCM       Data  ... Valor IPI Alíquota PIS  Valor PIS  \
# 0          1122  8207.50.11 2022-01-01  ...     10.91         0.65       1.38
# 1          1118  8202.39.00 2022-01-02  ...     32.87         0.65       4.15
# 2          1121  8207.50.11 2022-01-02  ...      4.06         0.65       0.51
# 3        1120-1  7310.29.90 2022-01-02  ...      0.00         0.65       0.12
# 4          1136  9032.89.11 2022-01-02  ...     17.77         0.65       1.25
#
#   Alíquota COFINS Valor COFINS DIFAL Regra Alíquota Interna  \
# 0               3         6.36  Por Dentro             20.0
# 1               3        19.15  Por Dentro             18.0
# 2               3         2.37  Por Dentro             18.0
# 3               3         0.57  Por Dentro             18.0
# 4               3         5.76  Por Dentro             18.0
#
#   DIFAL Valor Futuro  IRPJ  CSLL
# 0              44.14  2.65  2.38
# 1             113.52  7.98  7.18
# 2              14.04  0.99  0.89
# 3               3.36  0.24  0.21
# 4              34.15  2.40  2.16
#
# [5 rows x 34 columns]

# %%
import pandas as pd
df_ds = pd.read_csv('df_receitas.csv')
df_ds['Valor'].sum()
# Out:
# 4859504.66
